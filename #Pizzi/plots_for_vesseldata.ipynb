# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_bar_with_sem(data1, data2, font_style='Arial', font_size=12):
    # Calculate mean and SEM for each group
    mean1 = np.mean(data1)
    sem1 = np.std(data1) / np.sqrt(len(data1))
    mean2 = np.mean(data2)
    sem2 = np.std(data2) / np.sqrt(len(data2))

    # Plot means with error bars (SEM)
    bar_width = 0.35
    index = np.arange(2)
    bars = plt.bar(index, [mean1, mean2], bar_width, yerr=[sem1, sem2], color=['blue', 'green'], alpha=0.7)

    # Set font style and size for all labels
    plt.rcParams['font.family'] = font_style
    plt.rcParams['font.size'] = font_size

    plt.xlabel('Groups')
    plt.ylabel('Values')
    plt.xticks(index, ['Group 1', 'Group 2'])

    # Add legends for both groups
    plt.legend(bars, ['Group 1', 'Group 2'], frameon=False, loc='best')
    
    plt.title('Bar Plot of Means ± SEM for Two Groups')
    plt.show()

# %%
# Example data for two groups
group1_data = np.random.normal(loc=5, scale=1, size=100)
group2_data = np.random.normal(loc=7, scale=1.5, size=100)

# Import data for two groups

# Plot the bar plot with specified font style and size
plot_bar_with_sem(group1_data, group2_data, font_style='Arial', font_size=14)

# %%
#Histograms

"""
This code will display the histograms of both groups on two separate sets of axes.
Each subplot will have its own histogram, allowing for easy comparison between the two groups.
Adjustments to labels and titles ensure clarity and readability.
"""

import numpy as np
import matplotlib.pyplot as plt

# Generate example data for two groups
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)

# Calculate the bin edges
bins = np.linspace(min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)), 30)

# Create two separate subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot histogram for Group 1 on the first subplot
axs[0].hist(group1_data, bins=bins, color='blue', alpha=0.5)
axs[0].set_xlabel('Values')
axs[0].set_ylabel('Frequency')
axs[0].set_title('Group 1')

# Plot histogram for Group 2 on the second subplot
axs[1].hist(group2_data, bins=bins, color='green', alpha=0.5)
axs[1].set_xlabel('Values')
axs[1].set_ylabel('Frequency')
axs[1].set_title('Group 2')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate example data for two groups
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)

# Plot histograms for both groups on the same axis
plt.hist(group1_data, orientation='horizontal', color='blue', alpha=0.5, label='Group 1 (Rotated 180°)', bins=30)
plt.hist(group2_data, orientation='horizontal', color='green', alpha=0.5, label='Group 2', bins=30)

# Get the maximum count of both histograms
max_count = max(max(np.histogram(group1_data, bins=30)[0]), max(np.histogram(group2_data, bins=30)[0]))

# Set y-axis limits
plt.ylim(-0.5, max_count + 0.5)

# Invert y-axis
plt.gca().invert_yaxis()

# Set labels and title
plt.xlabel('Frequency')
plt.ylabel('Values')
plt.title('Histograms of Group 1 and Group 2')

# Add legend
plt.legend()

plt.show()

# %%
"""
In this code I've created two subplots, one for each group's histogram.
Group 2's histogram is plotted normally, while Group 1's histogram is flipped along the vertical axis using invert_xaxis().
Both subplots share the same x-axis to ensure the x-axes are touching.
"""

import numpy as np
import matplotlib.pyplot as plt

# Generate example data for two groups
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)

# Calculate the bin edges
bins = np.linspace(min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)), 30)

# Create two separate subplots
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

# Plot histogram for Group 2 on the first subplot
axs[0].hist(group2_data, bins=bins, color='green', alpha=0.5, orientation='horizontal')
axs[0].set_ylabel('Values')
axs[0].set_title('Group 2')
#axs[0].invert_yaxis()

# Plot histogram for Group 1 on the second subplot, flipped along the vertical axis
axs[1].hist(group1_data, bins=bins, color='blue', alpha=0.5, orientation='horizontal')
axs[1].invert_xaxis()
axs[1].set_xlabel('Frequency')
axs[1].set_ylabel('Values')
axs[1].set_title('Group 1')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate example data for two groups
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)

# Plot histograms for both groups on the same axis
plt.hist(group1_data, orientation='horizontal', color='blue', alpha=0.5, label='Group 1 (Rotated 180°)', bins=30)
plt.hist(group2_data, orientation='horizontal', color='green', alpha=0.5, label='Group 2', bins=30)

# Get the maximum count of both histograms
max_count = max(max(np.histogram(group1_data, bins=30)[0]), max(np.histogram(group2_data, bins=30)[0]))

# Set y-axis limits
plt.ylim(-0.5, max_count + 0.5)

# Invert y-axis
plt.gca().invert_yaxis()

# Set labels and title
plt.xlabel('Frequency')
plt.ylabel('Values')
plt.title('Histograms of Group 1 and Group 2')

# Add legend
plt.legend()

plt.show()

# %%
#As a function:

import numpy as np
import matplotlib.pyplot as plt

def plot_vertical_histograms(group1_data, group2_data, bins=30, figsize=(8, 8), font_type='Arial', font_size=12):
    """
    Plot histograms of two groups vertically with Group 1 histogram flipped along the vertical axis.

    Parameters:
    - group1_data: Array-like, data for Group 1.
    - group2_data: Array-like, data for Group 2.
    - bins: int or sequence of scalars or str, optional (default=30)
            If an integer, defines the number of equal-width bins in the range.
            If a sequence, defines the bin edges, including the rightmost edge, allowing for non-uniform bin widths.
            If a string, it defines the method used to calculate the optimal bin width, as defined by `np.histogram_bin_edges`.
    - figsize: tuple, optional (default=(8, 8))
               Width, height in inches.
    - font_style: str, optional (default='normal')
                  Font style.
    - font_size: int or float, optional (default=12)
                 Font size.

    Returns:
    - fig: Figure object
    - axs: Array of Axes objects
    """
    # Set font style and size
    plt.rcParams.update({'font.family': font_type, 'font.style': 'normal', 'font.size': font_size})

    # Calculate the bin edges
    hist_range = (min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)))
    bins = np.linspace(*hist_range, bins)

    # Create subplots
    fig, axs = plt.subplots(2, 1, figsize=figsize, sharex=True)

    # Plot histogram for Group 2 on the first subplot
    axs[0].hist(group2_data, bins=bins, color='green', alpha=0.5, orientation='horizontal')
    axs[0].set_ylabel('Values')
    axs[0].set_title('Group 2')

    # Plot histogram for Group 1 on the second subplot, flipped along the vertical axis
    axs[1].hist(group1_data, bins=bins, color='blue', alpha=0.5, orientation='horizontal')
    axs[1].invert_xaxis()
    axs[1].set_xlabel('Frequency')
    axs[1].set_ylabel('Values')
    axs[1].set_title('Group 1')

    plt.tight_layout()
    plt.show()

    return fig, axs

# Example usage:
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)
plot_vertical_histograms(group1_data, group2_data, figsize=(10, 8), font_type='Arial', font_size=14)


"""This function plot_vertical_histograms takes in the data for Group 1 and Group 2, and
optionally the number of bins, and plots the histograms vertically with Group 1 flipped
along the vertical axis. It returns the fig and axs objects for further customization if needed."""
# Out:
# 'This function plot_vertical_histograms takes in the data for Group 1 and Group 2, and\noptionally the number of bins, and plots the histograms vertically with Group 1 flipped\nalong the vertical axis. It returns the fig and axs objects for further customization if needed.'

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_cumulative_percent(group1_data, group2_data, bins=30, figsize=(8, 6), font_style='normal', font_size=12):
    """
    Plot cumulative percent histograms of two groups of input data.

    Parameters:
    - group1_data: Array-like, data for Group 1.
    - group2_data: Array-like, data for Group 2.
    - bins: int or sequence of scalars or str, optional (default=30)
            If an integer, defines the number of equal-width bins in the range.
            If a sequence, defines the bin edges, including the rightmost edge, allowing for non-uniform bin widths.
            If a string, it defines the method used to calculate the optimal bin width, as defined by `np.histogram_bin_edges`.
    - figsize: tuple, optional (default=(8, 6))
               Width, height in inches.
    - font_style: str, optional (default='normal')
                  Font style.
    - font_size: int or float, optional (default=12)
                 Font size.
    """
    # Set font style and size
    plt.rcParams.update({'font.family': 'Arial', 'font.style': font_style, 'font.size': font_size})

    # Calculate the bin edges
    hist_range = (min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)))
    bins = np.linspace(*hist_range, bins)

    # Create subplots
    fig, ax = plt.subplots(figsize=figsize)

    # Plot cumulative percent histograms for both groups
    weights1 = np.ones_like(group1_data) / len(group1_data)
    weights2 = np.ones_like(group2_data) / len(group2_data)

    ax.hist(group1_data, bins=bins, color='blue', alpha=0.5, cumulative=True, weights=weights1, label='Group 1', histtype='step', linewidth=2)
    ax.hist(group2_data, bins=bins, color='green', alpha=0.5, cumulative=True, weights=weights2, label='Group 2', histtype='step', linewidth=2)

    # Set labels and title
    ax.set_xlabel('Values')
    ax.set_ylabel('Cumulative Percent')
    ax.set_title('Cumulative Percent Histograms of Group 1 and Group 2')

    # Add legend
    ax.legend()

    plt.show()

# Example usage:
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)
plot_cumulative_percent(group1_data, group2_data, figsize=(10, 8), font_style='italic', font_size=14)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_cumulative_probability(group1_data, group2_data, bins=30, figsize=(8, 6), font_size=12):
    """
    Plot cumulative probability histograms of two groups of input data side by side.

    Parameters:
    - group1_data: Array-like, data for Group 1.
    - group2_data: Array-like, data for Group 2.
    - bins: int or sequence of scalars or str, optional (default=30)
            If an integer, defines the number of equal-width bins in the range.
            If a sequence, defines the bin edges, including the rightmost edge, allowing for non-uniform bin widths.
            If a string, it defines the method used to calculate the optimal bin width, as defined by `np.histogram_bin_edges`.
    - figsize: tuple, optional (default=(8, 6))
               Width, height in inches.
    - font_size: int or float, optional (default=12)
                 Font size.
    """
    # Set font type and size
    plt.rcParams.update({'font.family': 'Arial', 'font.style': 'normal', 'font.size': font_size})

    # Calculate the bin edges
    hist_range = (min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)))
    bins = np.linspace(*hist_range, bins)

    # Create subplots
    fig, ax = plt.subplots(figsize=figsize)

    # Plot cumulative probability histograms for both groups
    weights1_prob = np.ones_like(group1_data) / len(group1_data)
    weights2_prob = np.ones_like(group2_data) / len(group2_data)

    ax.hist(group1_data, bins=bins, color='blue', alpha=0.5, cumulative=True, weights=weights1_prob, label='Group 1', histtype='step', linewidth=2)
    ax.hist(group2_data, bins=bins, color='green', alpha=0.5, cumulative=True, weights=weights2_prob, label='Group 2', histtype='step', linewidth=2)

    # Set labels and title
    ax.set_xlabel('Values', fontsize=font_size)
    ax.set_ylabel('Cumulative Probability', fontsize=font_size)
    ax.set_title('Cumulative Probability Histograms of Group 1 and Group 2', fontsize=font_size)

    # Add legends for both groups
    plt.legend(['Group 1', 'Group 2'], frameon=False, loc='upper left')

    plt.show()

# Example usage:
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)
plot_cumulative_probability(group1_data, group2_data, figsize=(10, 8), font_size=14)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_cumulative_probability(group1_data, group2_data, bins=30, figsize=(8, 6), font_size=12):
    """
    Plot cumulative probability histograms of two groups of input data side by side.

    Parameters:
    - group1_data: Array-like, data for Group 1.
    - group2_data: Array-like, data for Group 2.
    - bins: int or sequence of scalars or str, optional (default=30)
            If an integer, defines the number of equal-width bins in the range.
            If a sequence, defines the bin edges, including the rightmost edge, allowing for non-uniform bin widths.
            If a string, it defines the method used to calculate the optimal bin width, as defined by `np.histogram_bin_edges`.
    - figsize: tuple, optional (default=(8, 6))
               Width, height in inches.
    - font_size: int or float, optional (default=12)
                 Font size.
    """
    # Set font type and size
    plt.rcParams.update({'font.family': 'Arial', 'font.style': 'normal', 'font.size': font_size})

    # Calculate the bin edges
    hist_range = (min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)))
    bins = np.linspace(*hist_range, bins)

    # Create subplots
    fig, ax = plt.subplots(figsize=figsize)

    # Plot cumulative probability histograms for both groups
    weights1_prob, bins1 = np.histogram(group1_data, bins=bins, density=True)
    weights2_prob, bins2 = np.histogram(group2_data, bins=bins, density=True)

    cum_prob1 = np.cumsum(weights1_prob)
    cum_prob2 = np.cumsum(weights2_prob)

    ax.plot(bins1[:-1], cum_prob1, color='blue', label='Group 1')
    ax.plot(bins2[:-1], cum_prob2, color='green', label='Group 2')

    # Set labels and title
    ax.set_xlabel('Values', fontsize=font_size)
    ax.set_ylabel('Cumulative Probability', fontsize=font_size)
    ax.set_title('Cumulative Probability Histograms of Group 1 and Group 2', fontsize=font_size)

    # Add legends for both groups
    plt.legend(frameon=False, loc='upper left')

    plt.show()

# Example usage:
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)
plot_cumulative_probability(group1_data, group2_data, figsize=(10, 8), font_size=14)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_cumulative_probability(group1_data, group2_data, bins=30, figsize=(8, 6), font_size=12):
    """
    Plot cumulative probability histograms of two groups of input data side by side.

    Parameters:
    - group1_data: Array-like, data for Group 1.
    - group2_data: Array-like, data for Group 2.
    - bins: int or sequence of scalars or str, optional (default=30)
            If an integer, defines the number of equal-width bins in the range.
            If a sequence, defines the bin edges, including the rightmost edge, allowing for non-uniform bin widths.
            If a string, it defines the method used to calculate the optimal bin width, as defined by `np.histogram_bin_edges`.
    - figsize: tuple, optional (default=(8, 6))
               Width, height in inches.
    - font_size: int or float, optional (default=12)
                 Font size.
    """
    # Set font type and size
    plt.rcParams.update({'font.family': 'Arial', 'font.style': 'normal', 'font.size': font_size})

    # Calculate the bin edges
    hist_range = (min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)))
    bins = np.linspace(*hist_range, bins)

    # Create subplots
    fig, ax = plt.subplots(figsize=figsize)

    # Plot cumulative probability histograms for both groups
    weights1_prob, bins1 = np.histogram(group1_data, bins=bins, density=True)
    weights2_prob, bins2 = np.histogram(group2_data, bins=bins, density=True)

    cum_prob1 = np.cumsum(weights1_prob)
    cum_prob2 = np.cumsum(weights2_prob)

    ax.plot(bins1[:-1], cum_prob1, color='blue', label='Group 1')
    ax.plot(bins2[:-1], cum_prob2, color='green', label='Group 2')

    # Set y-axis limits dynamically based on maximum cumulative probability value
    max_cum_prob = max(max(cum_prob1), max(cum_prob2))
    ax.set_ylim(0, max_cum_prob)

    # Set labels and title
    ax.set_xlabel('Values', fontsize=font_size)
    ax.set_ylabel('Cumulative Probability', fontsize=font_size)
    ax.set_title('Cumulative Probability Histograms of Group 1 and Group 2', fontsize=font_size)

    # Add legends for both groups
    plt.legend(frameon=False, loc='lower right')

    plt.show()

# Example usage:
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)
plot_cumulative_probability(group1_data, group2_data, figsize=(10, 8), font_size=14)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_cumulative_probability(group1_data, group2_data, bins=30, figsize=(8, 6), font_size=12):
    """
    Plot cumulative probability histograms of two groups of input data side by side.

    Parameters:
    - group1_data: Array-like, data for Group 1.
    - group2_data: Array-like, data for Group 2.
    - bins: int or sequence of scalars or str, optional (default=30)
            If an integer, defines the number of equal-width bins in the range.
            If a sequence, defines the bin edges, including the rightmost edge, allowing for non-uniform bin widths.
            If a string, it defines the method used to calculate the optimal bin width, as defined by `np.histogram_bin_edges`.
    - figsize: tuple, optional (default=(8, 6))
               Width, height in inches.
    - font_size: int or float, optional (default=12)
                 Font size.
    """
    # Set font type and size
    plt.rcParams.update({'font.family': 'Arial', 'font.style': 'normal', 'font.size': font_size})

    # Calculate the bin edges
    hist_range = (min(min(group1_data), min(group2_data)), max(max(group1_data), max(group2_data)))
    bins = np.linspace(*hist_range, bins)

    # Create subplots
    fig, ax = plt.subplots(figsize=figsize)

    # Plot cumulative probability histograms for both groups
    weights1_prob, bins1 = np.histogram(group1_data, bins=bins, density=True)
    weights2_prob, bins2 = np.histogram(group2_data, bins=bins, density=True)

    cum_prob1 = np.cumsum(weights1_prob)
    cum_prob2 = np.cumsum(weights2_prob)

    ax.plot(bins1[:-1], cum_prob1 * 100, color='blue', label='Group 1')
    ax.plot(bins2[:-1], cum_prob2 * 100, color='green', label='Group 2')

    # Set labels and title
    ax.set_xlabel('Values', fontsize=font_size)
    ax.set_ylabel('Cumulative Probability (%)', fontsize=font_size)
    ax.set_title('Cumulative Probability Histograms of Group 1 and Group 2', fontsize=font_size)

    # Add legends for both groups
    plt.legend(frameon=False, loc='lower right')

    plt.show()

# Example usage:
group1_data = np.random.normal(loc=0, scale=1, size=1000)
group2_data = np.random.normal(loc=2, scale=1.5, size=1000)
plot_cumulative_probability(group1_data, group2_data, figsize=(10, 8), font_size=14)
